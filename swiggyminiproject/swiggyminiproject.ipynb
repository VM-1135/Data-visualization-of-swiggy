# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('swiggy.csv')
print(df)
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df.isnull()
# Out:
#          ID   Area   City  Restaurant  Price  Avg ratings  Total ratings  \
# 0     False  False  False       False  False        False          False
# 1     False  False  False       False  False        False          False
# 2     False  False  False       False  False        False          False
# 3     False  False  False       False  False        False          False
# 4     False  False  False       False  False        False          False
# ...     ...    ...    ...         ...    ...          ...            ...
# 8675  False  False  False       False  False        False          False
# 8676  False  False  False       False  False        False          False
# 8677  False  False  False       False  False        False          False
# 8678  False  False  False       False  False        False          False
# 8679  False  False  False       False  False        False          False
#
#       Food type  Address  Delivery time
# 0         False    False          False
# ...

# %%
df.describe().T
# Out:
#                 count           mean            std    min      25%       50%  \
# ID             8680.0  244812.071429  158671.617188  211.0  72664.0  283442.0
# Price          8680.0     348.444470     230.940074    0.0    200.0     300.0
# Avg ratings    8680.0       3.655104       0.647629    2.0      2.9       3.9
# Total ratings  8680.0     156.634793     391.448014   20.0     50.0      80.0
# Delivery time  8680.0      53.967051      14.292335   20.0     44.0      53.0
#
#                      75%       max
# ID             393425.25  466928.0
# Price             400.00    2500.0
# Avg ratings         4.20       5.0
# Total ratings     100.00   10000.0
# Delivery time      64.00     109.0

# %%
df[df['Avg ratings'] > 3.4][['Restaurant','City','Food type']]
# Out:
#                   Restaurant       City  \
# 0                Tandoor Hut  Bangalore
# 1              Tunday Kababi  Bangalore
# 2                    Kim Lee  Bangalore
# 3          New Punjabi Hotel  Bangalore
# 4                        Nh8  Bangalore
# ...                      ...        ...
# 8509                Savister    Kolkata
# 8523              Chup Chaap  Ahmedabad
# 8540  Rotlo Gujarati Rasthal  Ahmedabad
# 8553           P Se Pavbhaji  Ahmedabad
# 8571                  Afresh    Chennai
#
#                                               Food type
# 0             Biryani,Chinese,North Indian,South Indian
# 1                                      Mughlai,Lucknowi
# 2                                               Chinese
# 3                  North Indian,Punjabi,Tandoor,Chinese
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...
# ...                                                 ...
# 8509                                   Snacks,Beverages
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
print(len (df[df.duplicated()]))
# Out:
# 0

# %%
df['Total ratings'].unique()
# Out:
# array([  100,   500,    50,    80,  1000,  5000,    20, 10000],
#       dtype=int64)

# %%
df['Address'].unique()
# Out:
# array(['5Th Block', 'Double Road', '80 Feet Road', ..., 'Umra Jakat',
#        'New Empire Cinema Kolkata', 'Sanjay Nagar New Bel Road'],
#       dtype=object)

# %%
df['Restaurant'].unique()
# Out:
# array(['Tandoor Hut', 'Tunday Kababi', 'Kim Lee', ...,
#        'Chinese Kitchen King', 'Shree Ram Paratha Wala', 'Sassy Street'],
#       dtype=object)

# %%
df['Avg ratings'].describe()
# Out:
# count    8680.000000
# mean        3.655104
# std         0.647629
# min         2.000000
# 25%         2.900000
# 50%         3.900000
# 75%         4.200000
# max         5.000000
# Name: Avg ratings, dtype: float64

# %%
df['Food type'].describe()
# Out:
# count       8680
# unique      3734
# top       Indian
# freq         389
# Name: Food type, dtype: object

# %%
df[df['City'] == 'Delhi']
# Out:
#           ID                        Area   City                Restaurant  \
# 123     5208               Paschim Vihar  Delhi                   Deli 63
# 151     6075               Paschim Vihar  Delhi           London Grill Co
# 176     7626               Vishnu Garden  Delhi          Sethi Restaurant
# 183     7859  Central Markt Punjabi Bagh  Delhi         Wok In The Clouds
# 191     8175               Paschim Vihar  Delhi            Chawla Kitchen
# ...      ...                         ...    ...                       ...
# 8663  461141                         Nsp  Delhi           New Oye Punjabi
# 8670  463051                      Rohini  Delhi          Zaika The Bakers
# 8676  465835                      Rohini  Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                      Rohini  Delhi      Chinese Kitchen King
# 8678  465990                      Rohini  Delhi    Shree Ram Paratha Wala
#
#        Price  Avg ratings  Total ratings  \
# ...

# %%
from scipy import stats
z=np.abs(stats.zscore(df['Price']))
z.sort_values()
# Out:
# 1544    0.006736
# 3213    0.006736
# 6966    0.006736
# 3221    0.006736
# 6971    0.006736
#           ...
# 1377    7.151858
# 2782    7.151858
# 4718    9.317047
# 3079    9.317047
# 2934    9.317047
# Name: Price, Length: 8680, dtype: float64

# %%
threshold_z= 8
outlier_indices=df[z>threshold_z]

# %%
ded=df

# %%
outlier_indices.index
# Out:
# Index([2934, 3079, 4718], dtype='int64')

# %%
df.drop(outlier_indices.index,inplace=True)
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
expensive=df[['Restaurant','Address','Price']].sort_values(by='Price',ascending=False).head(10)

# %%
cheap=df[['Restaurant','Address','Price']].sort_values(by='Price',ascending=True).head(10)

# %%
import seaborn as sns

# %%
a= sns.barplot(x ='Restaurant',y = 'Price',data = expensive)
a.set_xticklabels(labels = df['Restaurant'].to_list(),rotation=90)
plt.show()
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_8076\3295195152.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   a.set_xticklabels(labels = df['Restaurant'].to_list(),rotation=90)

# %%
ded=df
df.drop(df[df['Price']<51].index,inplace=True)

# %%
a= sns.barplot(x ='Restaurant',y = 'Price',data = cheap)
a.set_xticklabels(labels = df['Restaurant'].to_list(),rotation=90)
plt.show()
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_8076\2561521429.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   a.set_xticklabels(labels = df['Restaurant'].to_list(),rotation=90)

# %%
df.sort_values('Price',ascending=False)
# Out:
#           ID               Area       City                         Restaurant  \
# 1377   72003          Saki Naka     Mumbai                 Cafe Delhi Heights
# 8485  439628       Brigade Road  Bangalore  Lubov Patisserie By Frozen Bottle
# 2782  272388         Sangamvadi       Pune                        Conrad Pune
# 2757  266184        Bandra Area     Mumbai                           Yauatcha
# 5810  442443        Bandra West     Mumbai                  Sante Spa Cuisine
# ...      ...                ...        ...                                ...
# 6135  452169            Isanpur  Ahmedabad                    Tandoor Chicken
# 4593  389441        Koramangala  Bangalore                   The Tasty Planet
# 7593  151287  Sri Durga Enclave  Hyderabad                       Bhoomi Foods
# 8311  406947  Scruz Bandra East     Mumbai               A -1 Panipuri Center
# 7975  306955      Nana Varachha      Surat                 Moonlight Creamery
#
# ...
